# %%
# %load_ext sql

# %%
# %sql postgresql://appdev@data/appdev
# Out:
# 'Connected: appdev@appdev'

# %%
# %matplotlib inline

# %% [markdown]
# ## 1)

# %%
# %%sql CREATE VIEW thouslarg AS
# SELECT * FROM geoname
# ORDER BY population DESC
# limit 1000

# %%
result1 = %sql SELECT location[0],location[1] FROM thouslarg
# Out:
# 1000 rows affected.

# %%
result1.plot(marker='o',linestyle = 'None')

# %% [markdown]
# ## 2)
# Don't know if we're looking for the color or the colorIdentity property, so I've included both

# %%
magicresultcolors = %sql SELECT data->>'colors' AS ci, count(*) FROM cards GROUP BY ci ORDER BY COUNT(*) DESC limit 6
# Out:
# 6 rows affected.

# %%
magicresultcolors.bar()
# Out:
# <Container object of 6 artists>

# %%
magicresultcoloridentity = %sql SELECT data->>'colorIdentity' AS ci, count(*) FROM cards GROUP BY ci ORDER BY COUNT(*) DESC limit 6
# Out:
# 6 rows affected.

# %%
magicresultcoloridentity.bar()
# Out:
# <Container object of 6 artists>
